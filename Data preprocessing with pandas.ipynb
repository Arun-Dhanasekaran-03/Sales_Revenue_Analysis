# %% [markdown]
# # <b>Sales Revenue Analysis</b>
# Dataset used:
# - [geographic_product_demand_dataset_10M](https://www.kaggle.com/datasets/neuralsorcerer/geographic-product-demand-dataset)
#
# -By Arun Dhanasekaran

# %%
import pandas as pd
data=pd.read_csv("C:/ProgramData/MySQL/MySQL Server 9.2/Uploads/geographic_product_demand_dataset_10M.csv")
data
# Out:
#          Location ID       City        State Country  Latitude  Longitude  \
# 0                  1      Tokyo          NaN   Japan   35.6895   139.6917
# 1                  2  Hyderabad    Telangana   India   17.3850    78.4867
# 2                  3      Delhi        Delhi   India   28.7041    77.1025
# 3                  4    Toronto          NaN  Canada   43.6510   -79.3470
# 4                  5    Chicago           IL     USA   41.8781   -87.6298
# ...              ...        ...          ...     ...       ...        ...
# 9999995      9999996      Miami           FL     USA   25.7617   -80.1918
# 9999996      9999997   New York           NY     USA   40.7128   -74.0060
# 9999997      9999998    Kolkata  West Bengal   India   22.5726    88.3639
# 9999998      9999999      Miami           FL     USA   25.7617   -80.1918
# 9999999     10000000      Tokyo          NaN   Japan   35.6895   139.6917
#
#         Product ID   Product Category  Sales Volume  Sales Revenue        Date
# ...

# %%
#Checking for null/NaN values among columns
data.isna().sum()
# Out:
# Location ID               0
# City                      0
# State               3706818
# Country                   0
# Latitude                  0
# Longitude                 0
# Product ID                0
# Product Category          0
# Sales Volume              0
# Sales Revenue             0
# Date                      0
# dtype: int64

# %%
#Checking for duplicates values among columns
data.duplicated().any()
# Out:
# False
